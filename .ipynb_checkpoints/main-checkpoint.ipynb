# %% [markdown]
# ## Import Module

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import threading
import queue
import time
import re

# %% [markdown]
# ## Necessary Data

# %%
city_name_list = ["桃園市", 
                  "基隆市", 
                  "新竹市", 
                  "新竹縣", 
                  "宜蘭縣", 
                  "臺中市", 
                  "苗栗縣", 
                  "彰化縣", 
                  "南投縣", 
                  "雲林縣",
                  "臺南市",
                  "高雄市",
                  "嘉義市",
                  "嘉義縣",
                  "屏東縣",
                  "臺東縣",
                  "花蓮縣",
                  "澎湖縣",
                  "金門縣",
                  "連江縣"]

# %%
job_queue = queue.Queue()

for city in city_name_list:
    job_queue.put(city)

# %% [markdown]
# ## Worker Class

# %%
class Worker(threading.Thread):
    
    def __init__(self, job_queue, base_url):
        
        super().__init__()
        
        self.job_queue = job_queue
        self.base_url = base_url
        self.city_name = None
        self.driver = None
        
        
    def init_store_space(self):
        
        self.final_dict = {}
        self.name = []
        self.phone = []
        self.address = []
        
    
    def run(self):
        
        self.init_webdriver()
        
        while self.job_queue.qsize() >= 1:
            
            self.init_store_space()
            
            self.city_name = self.job_queue.get()
            
            if self.process_page() is False:
                continue
            
            if self.scrape_data() is False:
                continue
            
            self.convert_df()
            
        self.destruct_web_driver()
    
    
    def init_webdriver(self):
        
        self.driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver")
        
    
    def destruct_web_driver(self):
        
        self.driver.close()
        
        
    def process_page(self):
        
        self.driver.get("https://www.panasonic.com/tw/consumer/where-to-buy.html")
        time.sleep(3.5)
        
        try:
            self.driver.find_element_by_xpath('//*[@id="category1"]/option[1]').click()
            self.driver.find_element_by_xpath('//*[@id="a-search"]').send_keys(self.city_name)
            self.driver.find_element_by_xpath('//*[@id="searchsubmit"]').click()
            time.sleep(3.5)
            return True
        except:
            print(self.city_name + " " + "failed in process_page.")
            return False
        
    
    def scrape_data(self):
        
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")
        soup = soup.find_all("div", class_="shop")
        
        if len(soup) == 0:
            print(self.city_name + " " + "failed in scrape_data.")
            return False
        
        print(self.city_name + " " + "Scraped !")
        for idx in tqdm(range(len(soup))):
            
            shop = soup[idx]
            
            try:
                na = shop.find("h3", class_="subheader3").text
            except:
                na = None
            self.name.append(na)
            
            try:
                add = shop.find_all("p", class_="bodycopy1")[1].text
            except:
                add = None
            self.address.append(add)
            
            try:
                ph = shop.find_all("p", class_="bodycopy1")[3].text
                ph = re.findall("\d+-\d+", ph)[0]
            except:
                ph = None
            self.phone.append(ph)
            
        self.final_dict["公司名稱"] = self.name
        self.final_dict["地址"] = self.address
        self.final_dict["電話"] = self.phone
        
        
    def convert_df(self):
        
        df = pd.DataFrame.from_dict(self.final_dict)
        df.to_excel(self.city_name+".xlsx")

# %% [markdown]
# ## Main Driver

# %%
url = "https://www.panasonic.com/tw/consumer/where-to-buy.html"

worker1 = Worker(job_queue, url)
worker1.start()

worker2 = Worker(job_queue, url)
worker2.start()

worker3 = Worker(job_queue, url)
worker3.start()

worker4 = Worker(job_queue, url)
worker4.start()

worker5 = Worker(job_queue, url)
worker5.start()
# Out:
# 新竹縣 Scraped !
# 基隆市 Scraped !
# 新竹市 Scraped !
# 宜蘭縣 Scraped !
# d:\programming\pythondev\temp\venv\lib\site-packages\ipykernel_launcher.py:79: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Exception in thread []:
# Traceback (most recent call last):
#   File "c:\users\johnny\appdata\local\programs\python\python37\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-90-b4019475c2ff>", line 34, in run
#     if self.scrape_data() is False:
#   File "<ipython-input-90-b4019475c2ff>", line 87, in scrape_data
#     self.name.append(na)
# AttributeError: 'str' object has no attribute 'append'
#
# Exception in thread []:
# Traceback (most recent call last):
#   File "c:\users\johnny\appdata\local\programs\python\python37\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-90-b4019475c2ff>", line 34, in run
#     if self.scrape_data() is False:
#   File "<ipython-input-90-b4019475c2ff>", line 87, in scrape_data
#     self.name.append(na)
# AttributeError: 'str' object has no attribute 'append'
#
# Exception in thread []:
# Traceback (most recent call last):
#   File "c:\users\johnny\appdata\local\programs\python\python37\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-90-b4019475c2ff>", line 34, in run
#     if self.scrape_data() is False:
#   File "<ipython-input-90-b4019475c2ff>", line 87, in scrape_data
#     self.name.append(na)
# AttributeError: 'str' object has no attribute 'append'
#
# Exception in thread []:
# Traceback (most recent call last):
#   File "c:\users\johnny\appdata\local\programs\python\python37\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-90-b4019475c2ff>", line 34, in run
#     if self.scrape_data() is False:
#   File "<ipython-input-90-b4019475c2ff>", line 87, in scrape_data
#     self.name.append(na)
# AttributeError: 'str' object has no attribute 'append'
# 桃園市 Scraped !
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Exception in thread []:
# Traceback (most recent call last):
#   File "c:\users\johnny\appdata\local\programs\python\python37\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-90-b4019475c2ff>", line 34, in run
#     if self.scrape_data() is False:
#   File "<ipython-input-90-b4019475c2ff>", line 87, in scrape_data
#     self.name.append(na)
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# ## Debug

# %%
driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver")

# %%
driver.get("https://www.panasonic.com/tw/consumer/where-to-buy.html")

# %%
driver.find_element_by_xpath('//*[@id="category1"]/option[1]').click()

# %%
driver.find_element_by_xpath('//*[@id="a-search"]').send_keys("雲林縣")

# %%
driver.find_element_by_xpath('//*[@id="searchsubmit"]').click()

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
soup
# Out:
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths fullscreen" lang="zh" style="" xml:lang="zh" xmlns="http://www.w3.org/1999/xhtml"><!--  [if lt IE 7 ]> <html lang="en" class="no-js ie6"> <![endif]   --><!--  [if IE 7 ]> <html lang="en" class="no-js ie7"> <![endif]      --><!--  [if IE 8 ]> <html lang="en" class="no-js ie8"> <![endif]      --><!--  [if IE 9 ]> <html lang="en" class="no-js ie9"> <![endif]      --><!-- Build Version: 2.3.6.10_0 --><head class="at-element-marker" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script src="https://www.youtube.com/iframe_api"></script><script async="" id="www-widgetapi-script" src="https://s.ytimg.com/yts/jsbin/www-widgetapi-vfldn1jRM/www-widgetapi.js" type="text/javascript"></script><style>.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
# </style><link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans:400,500,700" rel="stylesheet" type="text/css"/><style>.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# </style><style>.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# </style><style>@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style>.gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}
# </style><style>.gm-style img{max-width: none;}.gm-style {font: 400 11px Roboto, Arial, sans-serif; text-decoration: none;}</style>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <iframe height="0" src="https://cdn.holmesmind.com/js/capmapping.htm?rtid=9026001" style="display:none;" width="0"></iframe><iframe height="0" style="display:none;" width="0"></iframe><iframe height="0" style="display:none;" width="0"></iframe><iframe height="0" src="https://cdn.holmesmind.com/js/capmapping.htm?rtid=9026002" style="display:none;" width="0"></iframe><iframe height="0" style="display:none;" width="0"></iframe><iframe height="0" style="display:none;" width="0"></iframe><script src="https://cdn.jsdelivr.net/gh/yEchKgnaHWFO/eland-tracker@1.1.3/eland_tracker_load.js"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script src="https://cdn.jsdelivr.net/gh/yEchKgnaHWFO/eland-tracker@1.1.3/eland_tracker_load.js"></script><script async="" src="https://www.google-analytics.com/gtm/js?id=OPT-N5WGZM6&amp;l=_globalDataLayer&amp;t=gwcglobal&amp;cid=1191782554.1597677488&amp;aip=true" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" src="https://s.yimg.com/wi/ytc.js"></script><script async="" src="https://connect.facebook.net/signals/config/2347126508839304?v=2.9.23&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/1788838264679335?v=2.9.23&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/2646867705395272?v=2.9.23&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/732328093569235?v=2.9.23&amp;r=stable"></script><script async="" src="//connect.facebook.net/en_US/fbevents.js"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-KQQ6JSX&amp;l=dataLayer2"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-T8VB6H"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-WCRQ3D&amp;l=_globalDataLayer"></script><script type="text/javascript">CQURLInfo={"requestPath":"/content/panasonic/tw/zh/consumer/where-to-buy","extension":"html","selectors":[],"systemId":"bff18c8a-634a-48b6-85bf-2114ec3e2010","runModes":"crx3,samplecontent,publish,crx3tar"};</script>
# <script src="/etc/clientlibs/granite/jquery_cache_-1A1jfTCvWqm4d1bDZudKQ.js" type="text/javascript"></script>
# <script src="/etc/clientlibs/granite/utils_cache_lg1KJMxvo7RztK4gGNXDZA.js" type="text/javascript"></script>
# <script src="/etc/clientlibs/granite/jquery/granite_cache_HNkn6LkV-kkxxsCGqM_aEA.js" type="text/javascript"></script>
# <script src="/etc/clientlibs/foundation/jquery_cache_18QuSiV7i5_jjRxT3SDQGg.js" type="text/javascript"></script>
# <script>
#     if(Window['CQ'] == undefined){
#         var CQ = {
#                 WCM:{MODE_EDIT:"true",getMode:function(){return false;}}
#         };
#     }
#     //console.log("CQ mode:" + CQ.WCM.getMode()); //uncomment to test
#     </script>
# <script src="/etc/designs/panasonic/common-clientlibs_cache_bVR3pyR5xBy5D-HDb1FUMQ.js" type="text/javascript"></script>
# <script src="/etc/designs/panasonic/common-libs_cache_vjIOZ7xQMFX3MVtXCOys7A.js" type="text/javascript"></script>
# <script src="/etc/designs/panasonic/wheretobuy-libs_cache_kSjSetpinMDG67BW2udSFg.js" type="text/javascript"></script>
# <link href="/etc/designs/panasonic/common-libs_cache_i-DAg1CO46nY0EyqOWjWTg.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/designs/panasonic/wheretobuy-libs_cache_Dd7wJc3KGwpusObCKvP3vQ.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/designs/panasonic/wheretobuy-suggest_cache_qshhwCDAaO4GBzHPXSpLOg.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/designs/panasonic-global-content-tw-zh_cache_Wya6A4Lje5LsIa_yj5RroA.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.panasonic.com/tw/consumer/where-to-buy.html" rel="canonical"/>
# <!--[if lte IE 9]>
# 	<script src="/etc/designs/panasonic/common-clientlibs/js/html5_cache_eNf8c3-5_pBn2a8KEnTQVw.js" type="text/javascript"></script>
# 	<link rel="stylesheet" href="/etc/designs/panasonic/common-clientlibs/css/ie_cache_xn7eZl-Uh0J-mF44qTvlnQ.css" />
# 	<link rel="stylesheet" href="/etc/designs/panasonic/common-clientlibs/css/ie9_cache_IT0mwI7gLHrry4yVEA4MxQ.css" />
# <![endif]-->
# <!--[if lt IE 9]><![endif]-->
# <!--[if lte IE 8]>
# <script src="/etc/designs/panasonic/common-clientlibs/js/selectivizr_cache_7OY9_at3nUoZOV0SEFUUqQ.js"></script>
# <link rel="stylesheet" href="/etc/designs/panasonic/common-clientlibs/css/gray.scale_cache_xwHmVigKJzdFUnOC1634rw.css" />
# <![endif]--><script src="/etc/designs/panasonic/eclinkage-libs_cache_PknMk4uTJ5IKwzhEVslfsg.js" type="text/javascript"></script>
# <script src="/etc/designs/panasonic/eccart-clientlibs/js/iframeResizer.min_cache_lpgOLWBCIPtkhcsLWq3DvA.js" type="text/javascript"></script>
# <script src="/etc/designs/panasonic/eclinkage-clientlibs/js/ext/onlineretailer-libs/ec-onlineretailer-libs_cache_1jAkVkBOt6xeu-ztq4Dp1Q.js" type="text/javascript"></script>
# <!-- eccart-libs -->
# <script src="/etc/designs/panasonic/eccart-libs_cache_roNfrxh0wBExu2CoMRa2rA.js" type="text/javascript"></script>
# <link href="/etc/designs/panasonic/eccart-libs_cache_NZ-xnY1juR1127Bd92WTig.css" rel="stylesheet" type="text/css"/>
# <!-- /eccart-libs -->
# <script type="text/javascript">
#         (function($){
#         	if (!("GwcCommon" in window)) {
#         		GwcCommon = {};
#         	}
#         	$.extend(GwcCommon, {
#         		isAlwaysOnSsl: true
#         	});
#         })(jQuery);
#  </script><link href="/etc/designs/panasonic/common-clientlibs/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/etc/designs/panasonic/common-clientlibs/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/etc/designs/panasonic/common-clientlibs/images/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <title>哪裡買 - Panasonic 台灣</title>
# <script src="//assets.adobedtm.com/9a3bddd6f912/cbb2fb6d641f/launch-dc69b1edf268.min.js"></script><script async="" src="https://assets.adobedtm.com/extensions/EP7b1fa4581fb94dd0961a981af9997765/AppMeasurement.min.js"></script><script async="" src="https://assets.adobedtm.com/extensions/EP7b1fa4581fb94dd0961a981af9997765/AppMeasurement_Module_ActivityMap.min.js"></script><style class="at-flicker-control" id="at-makers-style">
# .mboxDefault {visibility: hidden;}
# </style><script>
# function doProductViewByAT(mboxName, params, selector) {
#   if (adobe && adobe.target) {
#     if (document.querySelectorAll && document.querySelectorAll(selector).length > 0) {
#       adobe.target.getOffer({
#        "mbox": mboxName,
#        "params": params !== undefined ? params : {},
#        "success": function(offers) {
#          if (offers.length > 0) {
#            adobe.target.applyOffer({
#              "mbox": mboxName,
#              "timeout": 150000,
#              "selector": selector,
#              "offer": offers
#            });
#          } else {
#            jQuery(selector).css({"visibility": "visible"});
#          }
#        },
#        "error": function(status, error) {
#          if (console && console.log) {
#            _satellite.logger.info("SATELLITE[CUSTOM]: Error Occured! : mbox '" + mboxName + "' " + status + ": " + error, 1);
#            _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox '" + mboxName + "'", 1);
#             jQuery(selector + " .at-content").css({"visibility": "visible"});
#            console.log('Error', status, error);
#          }
#        },
#        "timeout": 1500,
#      });
#     } else {
#        _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox[X] '" + mboxName + "'", 1);
#        jQuery(selector + " .at-content").css({"visibility": "visible"});
#     }
#   } else {
#      _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox[X] '" + mboxName + "'", 1);
#      jQuery(selector + " .at-content").css({"visibility": "visible"});
#   }
# }
#
# function sendConversionEvent(params) {
#   if (adobe && adobe.target && params.productName !== undefined && params.productName !== null && params.productName !== '') {
#     adobe.target.trackEvent({
#       "mbox": "orderConfirmPage",
#       "params": {
#         "orderId": getPurchaseId(),
#         "orderTotal": 0,
#         "productPurchasedId": params.productId
#       }
#     });
#   }
#   function getPurchaseId() {
#     return "GWC" + new Date().getTime().toString(16) + Math.floor(10000000000*Math.random()).toString();
#   }
# }
#
# function sendEventMboxErrorOrNoResult(mboxName, params, selector) {
#   $(document).trigger('at-embedded-noresult.gwc', {
#     "mbox": mboxName,
#     "params": params !== undefined ? params : {},
#     "selector": selector
#   });
# }
#
# function doGetAndApplyOfferByAT(mboxName, params, selector) {
#   if (!params.recsItemCount) {
#     params.recsItemCount = 6;
#   }
#   params.selector = selector;
#   if (adobe && adobe.target) {
#     if (document.querySelectorAll && document.querySelectorAll(selector + " .at-offer").length > 0) {
#       adobe.target.getOffer({
#        "mbox": mboxName,
#        "params": params !== undefined ? params : {},
#        "success": function(offers) {
#          if (offers.length > 0) {
#            _satellite.logger.info("SATELLITE[CUSTOM]:  '" + mboxName + "'", 1);
#            offers[0].content = "<script type=\"text/javascript\">var mboxSelector = '" + selector + "';</" + "script>" + "<script type=\"text/javascript\">var recsItemCount = '" + params.recsItemCount + "';</" + "script>" + offers[0].content;
#            adobe.target.applyOffer({
#              "mbox": mboxName,
#              "timeout": 3000,
#              "selector": selector + " .at-offer",
#              "offer": offers
#            });
#          } else {
#            _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox[X] '" + mboxName + "'", 1);
#            jQuery(selector + " .at-content").css({"visibility": "visible"});
#            sendEventMboxErrorOrNoResult(mboxName, params, selector);
#          }
#        },
#        "error": function(status, error) {
#          if (console && console.log) {
#            _satellite.logger.info("SATELLITE[CUSTOM]: Error Occured! : mbox '" + mboxName + "' " + status + ": " + error, 1);
#            _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox '" + mboxName + "'", 1);
#             jQuery(selector + " .at-content").css({"visibility": "visible"});
#             sendEventMboxErrorOrNoResult(mboxName, params, selector);
#            console.log('Error', status, error);
#          }
#        },
#        "timeout": 3000,
#      });
#     } else {
#        _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox[X] '" + mboxName + "'", 1);
#        jQuery(selector + " .at-content").css({"visibility": "visible"});
#        sendEventMboxErrorOrNoResult(mboxName, params, selector);
#     }
#   } else {
#      _satellite.logger.info("SATELLITE[CUSTOM]: show default contents: mbox[X] '" + mboxName + "'", 1);
#      jQuery(selector + " .at-content").css({"visibility": "visible"});
#      sendEventMboxErrorOrNoResult(mboxName, params, selector);
#   }
# }
#
# try {
#   document.addEventListener(adobe.target.event.REQUEST_SUCCEEDED, function(e) {
#     window.ttMETA = window.ttMETA || {};
#     console.log(e.detail);
#     if (e.detail.mbox !== "") {
#       window.ttMETA[e.detail.mbox] = {};
#       var tokens = e.detail.responseTokens;
#       if (isEmpty(tokens)) {
#         return;
#       }
#       for (var key in tokens[tokens.length-1]) {
#         window.ttMETA[e.detail.mbox][key] = tokens[tokens.length-1][key];
#       }
#       // Call External Function
#       $(document).trigger('launch-rt-handle.gwc', {
#         mbox: e.detail.mbox,
#         ttMETA: ttMETA[e.detail.mbox]
#       });
#     }
#     console.log(window.ttMETA);
#     function isEmpty(val){
#       return (val === undefined || val == null || val.length <= 0) ? true : false;
#     }
#   });
# } catch (e) {
#
# }
#
# // Compatible with DTM
# var mboxCurrent = mboxCurrent || {
#     getDiv : function () {
#         return $(mboxSelector + ' .at-offer');
#     }
# };
#
# </script>
# <script type="text/javascript">
#
# 		glPageInfo = {
# 		    recsEntityIgnore:"0"
# 		};
# 		</script>
# <script type="text/javascript">
# </script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script type="text/javascript">
# //<![CDATA[
# if((navigator.userAgent.indexOf("iPhone") != -1)||((navigator.userAgent.indexOf("Android") != -1)&&(navigator.userAgent.indexOf("Mobile") != -1))||(navigator.userAgent.indexOf('iPod')  !=-1)){
# }else{
#  document.write('<meta name="viewport" content="width=980"/>');
# }
# //]]>
# </script><meta content="width=980" name="viewport"/>
# <script data-localstorage-save-https="true" id="storage-manager-client" src="/etc/designs/panasonic/common-clientlibs/js/storage-manager-client-libs-1.0.0_cache_H41ijxnhkgKB1N7_gN25eA.js" type="text/javascript"></script>
# <link href="/etc/designs/panasonic/wishlist-clientlibs/commonbars_cache_57ryDp97kWmtHojkFGRBvQ.css" rel="stylesheet" type="text/css"/>
# <script src="/etc/designs/panasonic/wishlist-clientlibs/commonbars_cache_F1hg5D2eNxrBYvHNoJwPxA.js" type="text/javascript"></script>
# <link href="/etc/designs/panasonic/common-clientlibs/css/common-font_tw_cache_dYFoA5eQInxxVd92BNLrEw.css" rel="stylesheet" type="text/css"/>
# <meta content="哪裡買 - Panasonic 台灣" property="og:title"/>
# <meta content="article" property="og:type"/>
# <!--<PageMap><DataObject type="thumbnail" /></PageMap>--><meta content="dL-IxwR7EnFYdzjNed-AOV5xaCgz4IRt-2eBIR7xxRI" name="google-site-verification"/><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/879882114/?random=1597677945936&amp;cv=9&amp;fst=1597677945936&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=768&amp;u_w=1024&amp;u_ah=768&amp;u_aw=1024&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg871&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;tiba=%E5%93%AA%E8%A3%A1%E8%B2%B7%20-%20Panasonic%20%E5%8F%B0%E7%81%A3&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="/etc/designs/panasonic/eclinkage-clientlibs/js/api/api-libs-if.js?v=2.0.2_0" type="text/javascript"></script><script src="/etc/designs/panasonic/eclinkage-clientlibs/js/api/linkages/000/api-libs-impl.js?v=2.0.2_0" type="text/javascript"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1003430218/?random=1597677946110&amp;cv=9&amp;fst=1597677946110&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=376635471&amp;u_h=768&amp;u_w=1024&amp;u_ah=768&amp;u_aw=1024&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;tiba=%E5%93%AA%E8%A3%A1%E8%B2%B7%20-%20Panasonic%20%E5%8F%B0%E7%81%A3&amp;hn=www.googleadservices.com&amp;rfmt=3&amp;fmt=4"></script><script onerror="ElandTracker.onErrorLoadJsFromCDN()" src="//cdn.jsdelivr.net/gh/yEchKgnaHWFO/eland-tracker@1.1.3/eland_fingerprint.js" type="text/javascript"></script><script onerror="ElandTracker.onErrorLoadJsFromCDN()" src="//cdn.jsdelivr.net/gh/yEchKgnaHWFO/eland-tracker@1.1.3/eland_tracker_utils.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.google.com/maps-api-v3/api/js/40/12/intl/zh_tw/common.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.google.com/maps-api-v3/api/js/40/12/intl/zh_tw/util.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.google.com/maps-api-v3/api/js/40/12/intl/zh_tw/map.js" type="text/javascript"></script><script src="/etc/designs/panasonic/eclinkage-clientlibs/js/ext/onlineretailer-libs/api/api-libs-if.js?v=2.0.2_0" type="text/javascript"></script><script charset="UTF-8" src="https://maps.google.com/maps-api-v3/api/js/40/12/intl/zh_tw/onion.js" type="text/javascript"></script><script src="/etc/designs/panasonic/eclinkage-clientlibs/js/ext/onlineretailer-libs/api/data-aggregators/010/api-libs-impl.js?v=2.0.2_0" type="text/javascript"></script><script src="/etc/designs/panasonic/eclinkage-clientlibs/js/ext/onlineretailer-libs/view/ec-common-libs.js?v=2.0.2_0" type="text/javascript"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/ViewportInfoService.GetViewportInfo?1m6&amp;1m2&amp;1d18.277789763694724&amp;2d110.72122645315073&amp;2m2&amp;1d29.174164430512736&amp;2d131.45948791580437&amp;2u7&amp;4szh-TW&amp;5e0&amp;6sm%40522000000&amp;7b0&amp;8e0&amp;callback=_xdc_._7qbrov&amp;client=gme-panasoniccorporation3&amp;token=122561" type="text/javascript"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/655767417/?random=1597677946344&amp;cv=9&amp;fst=1597677946344&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=768&amp;u_w=1024&amp;u_ah=768&amp;u_aw=1024&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa871&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;tiba=%E5%93%AA%E8%A3%A1%E8%B2%B7%20-%20Panasonic%20%E5%8F%B0%E7%81%A3&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script charset="UTF-8" src="https://maps.goog ...
# <!-- Global Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WCRQ3D" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# var _globalDataLayer=[{
#     pageGroup1: 'Where To Buy',
#     pageGroup2: '/zh/Consumer/哪裡買',
#     pageGroup3: '',
#     templateSubType: '',
#     pageId: ''
# }];
# </script>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','_globalDataLayer','GTM-WCRQ3D');
# </script>
# <!-- End Global Google Tag Manager -->
# <!-- Local Google Tag Manager -->
# <script>dataLayer=[];</script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-T8VB6H" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-T8VB6H');
# </script>
# <!-- End Local Google Tag Manager -->
# <!-- Local Google Tag Manager -->
# <script>dataLayer2=[];</script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KQQ6JSX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer2','GTM-KQQ6JSX');
# </script>
# <!-- End Local Google Tag Manager -->
# <!-- Eloqua Tag -->
# <script type="text/javascript">
#     var _elqQ = _elqQ || [];
# </script>
# <!-- Eloqua Tag -->
# <div id="page">
# <div class="masthead"><table cnty="tw" id="language-data" style="display:none">
# <tbody><tr data-selected="true" default="false" id="gwc-lang-sel-1" path="zh"><td></td></tr>
# </tbody></table>
# <script type="text/javascript">
# 		(function($){
# 			if (!("GwcCommon" in window)) {
# 				GwcCommon = {};
# 			}
# 			if (!("regionalData" in GwcCommon)) {
# 				GwcCommon.regionalData = {
# 					currentCountry: '',
# 					langs: []
# 				};
# 			}
# 			GwcCommon.regionalData.currentCountry = 'tw';
#
# 				GwcCommon.regionalData.langs.push({lang:"zh", isDefault:true, isCurrent:true});
#
# 		})(jQuery);
# 	</script>
# <header data-sw-version="V2" id="globalheader" role="banner">
# <div class="container">
# <div id="brandlogo">
# <a href="/tw/home.html"><img alt="Panasonic" class="copyguard" src="/content/panasonic/tw/zh/_jcr_content/masthead/primaryLogo.img.png/1575034881723.png"/><img alt="Panasonic" class="rwd copyguard" src="/etc/designs/panasonic/common-clientlibs/images/lgo-nav-global-panasonic-m-2x.png"/></a></div>
# <div id="search-normal">
# <button aria-controls="search-box" aria-expanded="false" class="search-normal-mobile-label"><span class="label" data-close-alt="關閉" data-open-alt="搜尋"><span>全站搜尋</span><img alt="搜尋" class="open" src="/etc/designs/panasonic/searchautocomplete-clientlibs/images/icn-search-w@2x.png"/><img alt="搜尋" class="close" src="/etc/designs/panasonic/searchautocomplete-clientlibs/images/icn-search-close-m.png"/></span></button>
# <div aria-hidden="true" class="search-normal-box" id="search-box">
# <div class="search-normal-box-in">
# <form action="/tw/search.html" id="searchformhead" method="get" role="search">
# <input autocomplete="on" class="field" id="s" name="q" placeholder="全站搜尋" title="Site Search" type="text"/>
# <input name="searchIn" type="hidden" value=""/>
# <input name="_charset_" type="hidden" value="utf-8"/>
# <button class="submit" type="submit"><img alt="搜尋" src="/etc/designs/panasonic/searchautocomplete-clientlibs/images/icn-search.png"/></button>
# </form>
# </div>
# </div>
# </div>
# <div id="mobile-navigation">
# <button aria-controls="nav-menu-mob" aria-expanded="false" class="toggleMenu"><span class="label"><img alt="Main menu" class="open" src="/etc/designs/panasonic/common-clientlibs/images/icn-nav-global-menu-m-2x.png"/><img alt="Main menu" class="close" src="/etc/designs/panasonic/searchautocomplete-clientlibs/images/icn-search-close-m.png"/></span></button>
# <nav aria-hidden="true" aria-label="Main menu" id="nav-menu-mob" role="navigation">
# <ul class="accordion typeTall"><li><a aria-controls="nav-menu-mob-accordion-0" aria-expanded="false" class="head accordion-head" href="#" rel="noopener" target="_blank"><span class="itembox"><span class="catname">個人、家庭產品</span></span></a><ul aria-hidden="true" class="accordion withImage" id="nav-menu-mob-accordion-0" style="display: none;"><li><a aria-controls="nav-menu-mob-accordion-1" aria-expanded="false" class="head accordion-head" href="#"><div class="itembox"><span class="img-element"><img alt="影音／相機／通訊" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/home-entertainment-wrapper_20190424.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">影音／相機／通訊</span></div></a><ul aria-hidden="true" class="accordion withImage" id="nav-menu-mob-accordion-1" style="display: none;"><li><a aria-controls="nav-menu-mob-accordion-2" aria-expanded="false" class="head accordion-head" href="#"><div class="itembox"><span class="img-element"><img alt="薄型電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65GZ2000W_wrapper_20191009.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">薄型電視</span></div></a><ul aria-hidden="true" class="accordion withImage" id="nav-menu-mob-accordion-2" style="display: none;"><li><a class="head" href="/tw/consumer/digital-av/tv/4k-japan-oled.html"><div class="itembox"><span class="img-element"><img alt="4K日本製OLED電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65GZ2000W_wrapper_20191009.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">4K日本製OLED電視</span></div></a></li><li><a class="head" href="/tw/consumer/digital-av/tv/4k-oled.html"><div class="itembox"><span class="img-element"><img alt="4K OLED電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65HZ1500W.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">4K OLED電視</span></div></a></li><li><a class="head" href="/tw/consumer/digital-av/tv/4k-japan-led.html"><div class="itembox"><span class="img-element"><img alt="4K日本製液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-49GX900W_wrapper_20191009.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">4K日本製液晶電視</span></div></a></li><li><a class="head" href="/tw/consumer/digital-av/tv/4k-led.html"><div class="itembox"><span class="img-element"><img alt="4K液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65HX900W.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">4K液晶電視</span></div></a></li><li><a class="head" href="/tw/consumer/digital-av/tv/led.html"><div class="itembox"><span class="img-element"><img alt="液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-43H400W.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">液晶電視</span></div></a></li><li><a class="head" href="/tw/consumer/digital-av/tv/accessories.html"><div class="itembox"><span class="img-element"><img alt="電視配件" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/digital-av-TY-ER3D4MW.png.thumb.92.123.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/></span><span class="catname">電視配件</span></div></a></li></ul></li><li><a aria-controls="nav-menu-mob-accordion-9" aria-expanded="false" class="head accordion-head" href="#"><div class="itembox"><span class="img-element"><img alt="數位相機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DC ...
# </div>
# <div class="accesible" id="globalheader-nav">
# <nav aria-label="Main menu" role="navigation">
# <ul class="main_menu">
# <li class="main-nav-root">
# <div class="main-nav-root__title"><a aria-expanded="false" class="link-products consumer link-megaPanel" data-panelnav-id="L2NvbnRlbnQvcGFuYXNvbmljL3R3L3poL3N5c3RlbS13cmFwcGVyL2NvbnN1bWVy" href="#" id="link-products" rel="noopener" target="_blank">個人、家庭產品</a></div>
# <div class="megapannel-wrapper">
# <div class="megapannel-container">
# <div class="megapannel-bg"><div class="megapannel-bg-in"></div></div>
# <div aria-hidden="true" class="megapannel" id="L2NvbnRlbnQvcGFuYXNvbmljL3R3L3poL3N5c3RlbS13cmFwcGVyL2NvbnN1bWVy">
# <div class="inpannel">
# <div class="panhead">
# <div class="container">
# <p class="inbread"><span tabindex="0">個人、家庭產品</span></p>
# <p class="closeit">
# <a class="btn-slide" href="javascript:void(0);">
# <img alt="關閉" height="9" src="/etc/designs/panasonic/common-clientlibs/images/icn-close.gif" width="9"/>
# </a>
# </p>
# </div>
# </div>
# <div class="parrays">
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="影音／相機／通訊" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/home-entertainment-wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">影音／相機／通訊</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="薄型電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65GZ2000W_wrapper_20191009.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">薄型電視</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/4k-japan-oled.html">
# <span class="img-element">
# <img alt="4K日本製OLED電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65GZ2000W_wrapper_20191009.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">4K日本製OLED電視</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/4k-oled.html">
# <span class="img-element">
# <img alt="4K OLED電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65HZ1500W.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">4K OLED電視</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/4k-japan-led.html">
# <span class="img-element">
# <img alt="4K日本製液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-49GX900W_wrapper_20191009.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">4K日本製液晶電視</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/4k-led.html">
# <span class="img-element">
# <img alt="4K液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-65HX900W.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">4K液晶電視</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/led.html">
# <span class="img-element">
# <img alt="液晶電視" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/TH-43H400W.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">液晶電視</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/tv/accessories.html">
# <span class="img-element">
# <img alt="電視配件" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/digital-av-TY-ER3D4MW.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">電視配件</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="數位相機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DC-S1R_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">數位相機</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/full-frame-cameras.html">
# <span class="img-element">
# <img alt="全片幅單眼相機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DC-S1R_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">全片幅單眼相機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/g-series-cameras.html">
# <span class="img-element">
# <img alt="單眼相機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DC-GH5S_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">單眼相機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/compact-camera.html">
# <span class="img-element">
# <img alt="類單眼相機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DC-LX100M2_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">類單眼相機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/full-frame-cameras-lenses.html">
# <span class="img-element">
# <img alt="全片幅鏡頭" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/S-X50_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">全片幅鏡頭</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/lumix-g-lenses.html">
# <span class="img-element">
# <img alt="單眼鏡頭" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/H-HS043_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">單眼鏡頭</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/lumix/accessories.html">
# <span class="img-element">
# <img alt="相機配件" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-Camera-Camcorder/DMW-FL360E_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">相機配件</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/video-player.html">
# <span class="img-element">
# <img alt="影音播放器" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/digital-av_DMP-BDT230.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">影音播放器</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="音響／收錄音機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/system-wrapper_audio.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">音響／收錄音機</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/audio/soundbar.html">
# <span class="img-element">
# <img alt="Soundbar" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/SC-HTB250GT-system-wrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">Soundbar</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/audio/micro-system.html">
# <span class="img-element">
# <img alt="組合音響" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/system-wrapper_audio.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">組合音響</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/audio/portable-audio.html">
# <span class="img-element">
# <img alt="手提收錄音機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/digital-av_RX-D53.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">手提收錄音機</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="耳機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/RP-HD605N_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">耳機</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/headphone/overhead.html">
# <span class="img-element">
# <img alt="耳罩式" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/RP-HD605N_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">耳罩式</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/headphone/ear-hook.html">
# <span class="img-element">
# <img alt="耳掛式" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/system-wrapper_ear_hook.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">耳掛式</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/headphone/in-ear.html">
# <span class="img-element">
# <img alt="耳塞式" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/system-wrapper_in_ear.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">耳塞式</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/headphone/true-wireless-stereo.html">
# <span class="img-element">
# <img alt="真無線藍牙耳機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Digital-AV/true-wireless-stereo_SystemWrapper_template.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">真無線藍牙耳機</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/telephone.html">
# <span class="img-element">
# <img alt="數位無線電話" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Communication-Lighting/KX-TGE610_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">數位無線電話</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/digital-av/fax.html">
# <span class="img-element">
# <img alt="傳真機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Communication-Lighting/communication-lighting_KX-FP207TW.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">傳真機</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="https://pmst.panasonic.com.tw/Air/PSPCindex.aspx?pmst_system-wrapper" rel="noopener" target="_blank">
# <span class="img-element">
# <img alt="空調商品" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Air-Conditioner/air-conditioner_20191017.png.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">空調商品</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/NR-F655WX_systemwrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">電冰箱</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/six-door.html">
# <span class="img-element">
# <img alt="六門電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/NR-F655WX_systemwrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">六門電冰箱</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/five-door.html">
# <span class="img-element">
# <img alt="五門電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/RGNR-E414VT_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">五門電冰箱</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/four-door.html">
# <span class="img-element">
# <img alt="四門電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/NR-D610NHGS_wrapper_20190426.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">四門電冰箱</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/three-door.html">
# <span class="img-element">
# <img alt="三門電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/NR-C610NHGS_wrapper_20190426.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">三門電冰箱</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/double-door.html">
# <span class="img-element">
# <img alt="雙門電冰箱" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/NR-B480TV_SystemWrapper_template.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">雙門電冰箱</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/refrigerator/freezer.html">
# <span class="img-element">
# <img alt="冷凍櫃" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Kitchen/FZ250A-S_systemwrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">冷凍櫃</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="洗衣機／乾衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/laundry_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">洗衣機／乾衣機</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/washing-machine/roller.html">
# <span class="img-element">
# <img alt="滾筒洗衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/laundry_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">滾筒洗衣機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="直立洗衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/NA-V220EBS_wrapper_20190426.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">直立洗衣機</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/washing-machine/vertical-washing-machine/inverter.html">
# <span class="img-element">
# <img alt="變頻洗衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/NA-V220EBS_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">變頻洗衣機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/washing-machine/vertical-washing-machine/fixed-frequency.html">
# <span class="img-element">
# <img alt="定頻洗衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/NA-120EB_wrapper_20171016.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">定頻洗衣機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/washing-machine/vertical-washing-machine/vertical-doubletub.html">
# <span class="img-element">
# <img alt="雙槽式洗衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/NA-W120G1_SystemWrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">雙槽式洗衣機</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/washing-machine/drying-machine.html">
# <span class="img-element">
# <img alt="乾衣機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/NH-70G_wrapper_20190426.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">乾衣機</span>
# </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="#">
# <span class="img-element">
# <img alt="生活小家電" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/System-Wrapper.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">生活小家電</span>
# </a>
# </div>
# <ul>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/air-conditioner/dehumidifier.html">
# <span class="img-element">
# <img alt="除濕機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Air-Conditioner/dehumidifier_191017.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">除濕機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/air-conditioner/air-purifier.html">
# <span class="img-element">
# <img alt="空氣清淨機" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/Air-Conditioner/F-VXP70W_Navigation_123_92_20171016.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">空氣清淨機</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# <a href="/tw/consumer/air-conditioner/electric-fan.html">
# <span class="img-element">
# <img alt="電風扇" data-src="/content/dam/Panasonic/tw/zh/System-Wrapper/House/F-H16EXD-K_wrapper_20190424.png" data-type="delay-load" src="/etc/designs/panasonic/common-clientlibs/images/blank.gif"/>
# </span>
# <span class="catname">電風扇</span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="parbase">
# ...
# c(d,"Category:click",f,!1)});a(".topicssocial .snsgadgets__icon a").on("click",function(){var b=a(this);c(p(b,"SNSTimeline"),"SNS: Selector - "+b.children("img").attr("alt"))});a(".topicssocial .topicssocial__frame .topicssocial__btn a").on("click",function(){var b=a(this);0<b.closest(".topicssocial__frame__in").find(".snsgadgets").length?c(p(b,"SNSTimeline"),"More: click",b.attr("href"),!1):c(p(b,"RSSNews"),"More: click",b.attr("href"),!1)});a(document).on("mousedown",".userbar__browseall \x3e a",
# function(){c("User Bar",e(a(this))+": click")});a("#globalfooter .pagefooter__topagetop button").on("click",function(){c("Back to Top (floating button)","click")})});</script><script id="" type="text/javascript">if("undefined"===typeof _gat)var _gat={_getTrackerByName:function(){return{_trackPageview:function(){},_trackEvent:function(){}}}};</script><script id="" type="text/javascript">"undefined"!==typeof addthis&&addthis.addEventListener("addthis.menu.share",addthisShareHandler);function addthisShareHandler(a){ga("gwclocal.send","social",a.data.service,"share",a.data.url)}
# jQuery(function(a){a(document).on("mousedown","a",function(b){(b=a(this).attr("href"))&&b.match("^http[^/]+//[^/]*")&&0>b.indexOf(window.location.hostname)&&(ga("gwclocal.send","event","ExternalLink","click",b),ga("gwclocal.send","pageview","/vpv/externals/"+b))});a("#searchformhead").on("submit",function(b){b=a("input[name\x3dq]",a(this)).val();ga("gwclocal.send","event","SiteSearch","query",b);for(b=(new Date).getTime()+100;(new Date).getTime()<b;);});var g=function(b,a,c){ga("gwclocal.send","event",
# b,"click",a,c);ga("gwclocal.send","pageview","/vpv/CTAs/"+b+"/"+a)},d=function(b,a){ga("gwclocal.send","event",b,"click",a)};a("#userbar-cart").on("mousedown","a",function(b){d("BASKETbutton",document.title)});a("#userbar-cartlist-in .btn-checkout").on("mousedown","a",function(b){b=a(this).text();d(e(b)+"_BASKET",document.title)});a(document).on("mousedown","#browsebar-utils a, #browsebar-buyslide a, .category-products .product-box .buy-btn a, #compare-sortable .product-box .buy-btn a",function(b){b=
# a(this).text();g(e(b),document.title)});a(document).on("mousedown",".category-products .product-energy a, #compare-sortable .product-energy a",function(b){d("EnergyLabel",document.title)});a(document).on("mouseenter","#buymenu .buymenu-energylable a",function(b){d("EnergyLabel",document.title)});a(document).on("mouseenter","#buymenu .shipping a",function(b){d("ShippingCosts",document.title)});a(document).on("mouseenter","#buymenu .buymenu-caption-moreinfo a",function(b){d("MoreInfo",document.title)});
# a(document).on("mousedown","#buymenu .buymenu-colorselector a",function(b){a(this).hasClass("disable")||(b=a(this).find("img").eq(0).attr("alt"),d(e(b),document.title))});a(document).on("mousedown","#buymenu .btn-addCart a",function(b){b=a(this).text();var l=parseInt(a(this).parents(".buymenu-right").find(".buynowNumber").val(),10);l?g(e(b),document.title,l):g(e(b),document.title)});a(document).on("mousedown","#buymenu .btn-wheretobuy a",function(b){b=a(this).text();d(e(b),document.title)});a(document).on("mousedown",
# "#buysuccess .btn-checkout a",function(b){b=a(this).text();g(e(b),document.title)});a(document).on("mousedown","#buysuccess .btn-continue a",function(b){b=a(this).text();d(e(b),document.title)});a(document).on("mousedown","#buywindow-bg .btn-close",function(b){d("Close",document.title)});a(".specs-data .seeall a").click(function(b){ga("gwclocal.send","pageview",location.pathname+"#ViewSpecifications")});a(".support-content dd a").click(function(b){try{var a=b.target||b.srcElement,c="/"==a.pathname.charAt(0)?
# a.pathname:"/"+a.pathname;ga("gwclocal.send","pageview",c)}catch(r){}});a(".getinspired-layout .paginator a").each(function(b,c){a(c).click(function(b){b=a(".getinspired-slider .slide-block").eq(0).find("iframe");0<b.length&&ga("gwclocal.send","event","Movie","play",b.attr("src"))})});a("#wheretobuy #geolocated").click(function(){ga("gwclocal.send","event","WheretoBuy","geolocate")});a("#wheretobuy #searchsubmit").on("mousedown",function(){var b=a("#category1 option:selected").text(),c=a("#category2 option:selected").text(),
# d=a("input[name\x3d'distance']:checked").parent().text(),f=a("#a-search").val();b=e(b);c=e(c);d=e(d);f=e(f);f=b+":"+c+":"+d+":"+f;ga("gwclocal.send","event","WheretoBuy","search",f)});a(document).on("click","#wheretobuy .shop .moreinfo a",function(){if(a(this).find(".see").is(":hidden")){var b=a(this).closest(".cols").find("h3").text();ga("gwclocal.send","event","WheretoBuy","storeInfo",b)}});var c=function(b,a){ga("gwclocal.send","event","WheretoBuy","storeLink:"+b,a)};a(document).on("mousedown",
# "#wheretobuy .search_results .shopdata .phone a",function(){var b=a(this).text(),d=a(this).closest(".shopdata").prev("h3").text();c(b,d)});a(document).on("mousedown","#wheretobuy .map a.email, #wheretobuy .map a.website",function(){var b=a(this).text(),d=a(this).closest(".gmapLabel").find(".shopname").text();c(b,d)});a(document).on("mousedown","#wheretobuy .search_results .onlineshop .shoplogo a, #wheretobuy .search_results .onlineshop .shopdata a",function(){var b=a(this).closest(".onlineshop").find("h3").text();
# c("online",b)});a(document).on("tabsactivate","#snsgadgets",function(b,a){var c=a.newTab.first().find(".ui-tabs-anchor \x3e img").attr("alt");ga("gwclocal.send","event","SNS","gadgetsClick",c)});a(".seeallreviews a").click(function(){ga("gwclocal.send","pageview",location.pathname+"#ReadAndWriteUserReviews")});a("#ratings-form .reviews-buttons a").click(function(){var b=a(".spech_title .header3").text(),c=parseInt(a("#ratings-form input:radio[name\x3drating]:checked").val(),10);ga("gwclocal.send",
# "event","UserReview","submit",b,c)});var f=[];a(".demo-visual-btn a").click(function(){var b=a(this).closest("section").find("h2").text();0>jQuery.inArray(b,f)&&(ga("gwclocal.send","event","ICM","click",b),f.push(b))});a(document).on("click",".scene7Thumbs-section .thumb-block",function(){var b=a(this).data("$slide_block");"undefined"!==typeof b&&(b=b.find(".slide-content"),"undefined"!==typeof b.data("asset")?ga("gwclocal.send","event","scene7-tumbs","click",b.data("type")+":"+b.data("asset"),{nonInteraction:1}):
# ga("gwclocal.send","event","scene7-tumbs","click",b.data("type"),{nonInteraction:1}))});var m=a("#bookmarkbar"),h,k=function(){return m.find("a.selected").last().text()},e=function(b){return b.replace(/^\s+/,"").replace(/\s+$/,"")},n=function(b){setTimeout(function(){h!==b&&b===k()&&(h=b,ga("gwclocal.send","event","section",e(h),{nonInteraction:1}))},3E3)};if(""!==k()){n(k());a(window).scroll(function(b){b=k();b!==h&&n(b)});a(".tabs, .product-tabs").on("tabsactivate",function(b,a){ga("gwclocal.send",
# "event","tab",a.newTab.text(),{nonInteraction:1})});var p=!0;a(document).on("slidestop","#overview-360",function(b){p&&(ga("gwclocal.send","event","360View","slide",{nonInteraction:1}),p=!1)});var q=function(){ga("gwclocal.send","event","SeeMore","click",{nonInteraction:1})};a("a#seemore").on("click",q)}});
# (function(){var a=window.onYouTubeIframeAPIReady,g=function(a){1==a.data&&ga("gwclocal.send","event","Youtube","play",a.target.getVideoUrl())};window.onYouTubeIframeAPIReady=function(){jQuery.isFunction(a)&&a();jQuery(function(a){a(window).on("load",function(){if("undefined"===typeof youtubeVideos||null===youtubeVideos){var c=a('iframe[src*\x3d"www.youtube.com"]');c.each(function(a,c){new YT.Player(c,{events:{onStateChange:function(a){g(a)}}})})}})})};if("undefined"!==typeof youtubeVideos&&null!==
# youtubeVideos&&jQuery.isArray(youtubeVideos)){var d=function(a){a.addEventListener("onReady",function(a){a.target.addEventListener("onStateChange",g)})};youtubeVideos.push=function(){for(var a=0,f=arguments.length;a<f;a++){this[this.length]=arguments[a];try{d(arguments[a])}catch(m){}}return this.length}}})();</script><script id="" type="text/javascript">ga("require","displayfeatures");</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","732328093569235");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=294379037437548&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">var google_conversion_id=1003430218,google_custom_params=window.google_tag_params,google_remarketing_only=!0;</script>
# <script id="" src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script><script id="" type="text/javascript">var meta=document.createElement("meta");meta.name="google-site-verification";meta.content="dL-IxwR7EnFYdzjNed-AOV5xaCgz4IRt-2eBIR7xxRI";document.getElementsByTagName("head")[0].appendChild(meta);</script><script id="" type="text/javascript">(function(d,a,b,f,e){d[e]=d[e]||[];d[e].push({projectId:"10000",properties:{pixelId:"10040205"}});var c=a.createElement(b);c.src=f;c.async=!0;c.onload=c.onreadystatechange=function(){var a=this.readyState,c=d[e];if(!a||"complete"==a||"loaded"==a)try{var b=YAHOO.ywa.I13N.fireBeacon;d[e]=[];d[e].push=function(a){b([a])};b(c)}catch(g){}};a=a.getElementsByTagName(b)[0];b=a.parentNode;b.insertBefore(c,a)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script><script id="" src="//dmp.eland-tech.com/dmpreceiver/eland_tracker.js" type="text/javascript"></script><script id="" src="//cdn.doublemax.net/js/rtid.js" type="text/javascript"></script><script id="" type="text/javascript">jQuery(document).ready(function(a){var b="gwclocal";a(document).on("mousedown","#browsebar-name \x3e .sharebtn li a",function(){var c={eventCategory:"SNS",eventAction:"AddThisLink",eventLabel:a(this).context.title},d={hitType:"event"};"Buy Button"!==c.eventCategory&&ga(b+".set","metric1",void 0);ga(b+".send",a.extend({},d,c))})});</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","2646867705395272");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=2646867705395272&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1788838264679335");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1788838264679335&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" src="https://www.googletagmanager.com/gtag/js?id=AW-655767417" type="text/javascript"></script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","2347126508839304");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=2347126508839304&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <iframe id="storage-manager-frame" src="https://www.panasonic.com/servlet/storage-manager.html" style="display: none;"></iframe><span id="product-name-buy-button" style="display:none !important;"></span><span id="section-name-buy-button" style="display:none !important;"></span><script class="ywa-10000" defer="" id="ywa-1597677946109-739223" src="https://sp.analytics.yahoo.com/sp.pl?a=10000&amp;d=Mon%2C%2017%20Aug%202020%2015%3A25%3A46%20GMT&amp;n=-8&amp;b=%E5%93%AA%E8%A3%A1%E8%B2%B7%20-%20Panasonic%20%E5%8F%B0%E7%81%A3&amp;.yp=10040205&amp;f=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;enc=UTF-8&amp;tagmgr=gtm%2Cadobe" type="application/javascript"></script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1003430218/?guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <script id="" type="text/javascript">var dataJson={source:"panasonic_official",trackType:"view",targetType:"_zh_Consumer_哪裡買",trackSubfolderDepth:1,subFolder:"google_gtm",ecInfo:{itemName:"https:\/\/www.panasonic.com\/tw\/consumer\/where-to-buy.html",memberID:""}};ElandTracker.Track(dataJson);</script><div class="mbox-name-SiteCatalyst: event at-element-marker" data-at-mbox-name="SiteCatalyst: event" id="_AdobeAnalytics_AA-AT"></div><script id="" type="text/javascript">document.cookie="global_category\x3d"+encodeURIComponent(google_tag_manager["GTM-WCRQ3D"].macro(54))+"; path\x3d/";</script>
# <script id="" src="//dmp.eland-tech.com/dmpreceiver/eland_tracker.js" type="text/javascript"></script>
# <script id="" type="text/javascript">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","AW-655767417");</script>
# <script id="" src="https://cdn.doublemax.net/dmp/cft/tracker.js" type="text/javascript"></script>
# <script id="" type="text/javascript">clickforce_rtid("9026001");ElandTracker.Track({source:"CAP9026",trackType:"view",trackSubfolderDepth:3,targetType:"usual"});clickforce_rtid("9026002");ElandTracker.Track({source:"CAP9026",trackType:"view",trackSubfolderDepth:3,targetType:"pageview"});window.cft=window.cft||function(){(cft.q=cft.q||[]).push([].slice.call(arguments))};cft("setSiteId","CF-190800042636");cft("setEnableCookie");cft("setViewPercentage");cft("setTPCookie");</script><iframe alt="elandTracker" src="//dmp.eland-tech.com/dmpreceiver/viewreceiver?DMP_SR=CAP9026&amp;target=usual&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;refer_url=&amp;platform=PC&amp;os=Windows&amp;browser=Chrome&amp;subDomain=tw-consumer-where-to-buy.html-&amp;ce=1&amp;fp2=31d1db3fa905eddc0db8776a879d0f64&amp;" style="width: 0px; height: 0px; border: 0px; display: none;" title="elandTracker"></iframe><iframe alt="elandTracker" src="//dmp.eland-tech.com/dmpreceiver/viewreceiver?DMP_SR=CAP9026&amp;target=pageview&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;refer_url=&amp;platform=PC&amp;os=Windows&amp;browser=Chrome&amp;subDomain=tw-consumer-where-to-buy.html-&amp;ce=1&amp;fp2=31d1db3fa905eddc0db8776a879d0f64&amp;" style="width: 0px; height: 0px; border: 0px; display: none;" title="elandTracker"></iframe><iframe alt="elandTracker" src="//dmp.eland-tech.com/dmpreceiver/viewreceiver?DMP_SR=panasonic_official&amp;target=_zh_Consumer_哪裡買&amp;url=https%3A%2F%2Fwww.panasonic.com%2Ftw%2Fconsumer%2Fwhere-to-buy.html&amp;refer_url=&amp;platform=PC&amp;os=Windows&amp;browser=Chrome&amp;subDomain=google_gtm&amp;ce=1&amp;item_name=https://www.panasonic.com/tw/consumer/where-to-buy.html&amp;fp2=31d1db3fa905eddc0db8776a879d0f64&amp;" style="width: 0px; height: 0px; border: 0px; display: none;" title="elandTracker"></iframe></body></html>

# %%
soup = soup.find_all("div", class_="shop")

# %%
len(soup)
# Out:
# 15

# %%
soup[14].find("h3", class_="subheader3").text
# Out:
# '宏達電氣行'

# %%
soup[14].find_all("p", class_="bodycopy1")[1].text
# Out:
# '雲林縣西螺鎮河南里埔心路81號'

# %%
phone = soup[14].find_all("p", class_="bodycopy1")[3].text

# %%
re.findall("\d+-\d+", phone)
# Out:
# ['05-5862959']
